# %% [markdown]
# <a href="https://colab.research.google.com/github/hungryjins/DA_portfolio/blob/main/Chapter18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** Chapter 18 **
# ** ┗ Development of indicators of e -commerce data use **
# ---
# > ** Contents (context) **
#
# * Looking at the problem situation and data
# * Definition of problem solving process
# * 🥉SESSION 1 -「Search for Service Usage」
# * 🥈SESSION 2 -「Indicator Planning and Data Extraction」
# * 🥇SESSION 3 -「RFM usage service level measurement」

# %%
# ▶ Remove Warnings
import warnings
warnings.filterwarnings('ignore')

# ▶ Google Drive Mount
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/DA portfolio/DA_colab/18_Developing Metrics Using E-commerce Data')
os.getcwd()
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/DA portfolio/DA_colab/18_Developing Metrics Using E-commerce Data'

# %% [markdown]
# ## ** Looking at the problem situation and data **
# ---
# > ** Scenario ** ⛳ (Marketer, Service Planner)
#
# ``
# Company A operates an open market platform.Users have risen rapidly since launch, but are now in stagnation.Current service use level
# I would like to perform various analysis to determine what is going on and how it has changed since its launch.
#
# ``

# %% [markdown]
# > ** Looking at the data **
#
# * E -Commerce Online Purchase Data
# * Data specification ⬇
#
# | INVOICENO | Stockcode | Description | Quantity |
# | ----: | ---: | ----: |: ---: | ---: | ---: ---: ---: ----: |
# | Voice Number | Inventory Code | Details | Quantity | Valley Date | Price per unit | Customer ID | Nara |

# %%
# ▶ Data read
import pandas as pd
import numpy as np
df=pd.read_csv('chapter18_e_commerce.csv', encoding='ISO-8859-1')
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## ** Problem solving process definition **
# ---
# > ** ** of the problem
#
# ``
# ▶ After launching, operating profit due to service stagnation, decrease in the number of customers used
# ``
#
# > ** Expected effect **
#
# ``
# ▶ Operating profit through establishing and execution of stagnation causes, increasing the number of customers used
# ``
#
# > ** Solution **
#
# ``
# ▶ Identify the use of purchasing data utilization service (indicator planning)
# ▶ Session 1 🥉
# -DATA pretreatment
# ▶ Session 2 🥈
# -Are understanding of the RFM model and how to set each indicator
# ▶ Session 3 🥇
# -RFM utilization service indicator planning and development
# ``
#
# > ** Performance measurement **
#
# ``
# ▶ Identify the status of use of indicators
# ``
#
# > ** Public application **
#
# ``
# ▶ Issuance of data insights
# ▶ Monitoring and issues after developing the developed indicator dashboard (*bi toll)
# ``
#
# > ** Main code preview **
#
# ``
# ▶ Session 1 → DF [DF ['Quantity']> 0]
# ▶ Session 2 → STR.Split ('') .str [0], DF.GROUPBY ('Customerid', As_index
# ▶ Session 3 → minmax_scale, dt.trftime ("%y-%m")
# ``

# %% [markdown]
# ## ** 🥉Session 1 **
# ** ┗ Service type exploration **
# ---

# %% [markdown]
# ### · Data pretreatment
# ---
# * Check the basic information of the collected data
#
# (1) Data Shape Check
#
# (2) Check Data Type
#
# (3) NULL value check (※ Data of empty values)
#
# (4) Outlier verification (※ Data beyond normal category)

# %%
# ▶ Data type confirmation
# ▶ 541,909 ROW, 8 COL
print('df', df.shape)
# Out:
# df (541909, 8)

# %%
# ▶ Data Type Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# ▶ Check NULL value
print(df.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# ▶ Outlier verification
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# ▶ null value drop
# ▶ NULL VALUE DROP based on Customerid

df.dropna(subset=['CustomerID'], how='all', inplace=True)
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# ▶ Distplot use negative data distribution confirmation
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['dark_background'])

sns.distplot(df['Quantity'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
# ▶ Uniprice negative value removal
df = df[df['UnitPrice']>0]
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406789.000000  406789.000000  406789.000000
# mean       12.028359       3.460811   15287.795830
# std       247.927842      69.318561    1713.573064
# min    -80995.000000       0.001000   12346.000000
# 25%         2.000000       1.250000   13954.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# ▶ Quantity negative value removal
df = df[df['Quantity']>0]
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  397884.000000  397884.000000  397884.000000
# mean       12.988238       3.116488   15294.423453
# std       179.331775      22.097877    1713.141560
# min         1.000000       0.001000   12346.000000
# 25%         2.000000       1.250000   13969.000000
# 50%         6.000000       1.950000   15159.000000
# 75%        12.000000       3.750000   16795.000000
# max     80995.000000    8142.750000   18287.000000

# %%
# 541909, 397884
df.shape
# Out:
# (397884, 8)

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# ▶ Number of customers (4,338 people), used goods (5,167,812 cases)
df['CustomerID'].nunique(), df['Quantity'].sum(), df['Country'].nunique()
# Out:
# (4338, np.int64(5167812), 37)

# %%
# ▶ Number of average purchases per person (91 cases)
df.groupby('CustomerID')['InvoiceNo'].count().mean()
# Out:
# np.float64(91.72060857538035)

# %% [markdown]
# ## ** 🥈Session 2 **
# ** ┗ Indicator planning and data extraction **
# ---

# %%
from re import A
from PIL import Image
Image.open('img18.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1025x488>

# %% [markdown]
# ### · Recency
# ---

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# ▶ Extract only date data on the invoice data using Split
df['InvoiceDate'].str.split(' ').str[0]
# Out:
# 0         12/1/2010
# 1         12/1/2010
# 2         12/1/2010
# 3         12/1/2010
# 4         12/1/2010
#             ...
# 541904    12/9/2011
# 541905    12/9/2011
# 541906    12/9/2011
# 541907    12/9/2011
# 541908    12/9/2011
# Name: InvoiceDate, Length: 397884, dtype: object

# %%
# ▶ Datatime index
import pandas as pd
df['Date'] = pd.to_datetime(df['InvoiceDate'].str.split(' ').str[0])
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country       Date
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom 2010-12-01
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom 2010-12-01
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01

# %%
df['Date'].min(), df['Date'].max()
# Out:
# (Timestamp('2010-12-01 00:00:00'), Timestamp('2011-12-09 00:00:00'))

# %%
# ▶ The last purchase date for each customer ID
recency_df = df.groupby('CustomerID',as_index=False)['Date'].max()
recency_df.columns = ['CustomerID','LastPurchaseDate']
recency_df.head()
# Out:
#    CustomerID LastPurchaseDate
# 0     12346.0       2011-01-18
# 1     12347.0       2011-12-07
# 2     12348.0       2011-09-25
# 3     12349.0       2011-11-21
# 4     12350.0       2011-02-02

# %%
# ▶ To calculate how many days have passed from the last day of the customer
recency_df['Recency'] = recency_df['LastPurchaseDate'].apply(lambda x : (df['Date'].max() - x).days)
recency_df.drop(columns=['LastPurchaseDate'],inplace=True)

# %%
recency_df.head(5)
# Out:
#    CustomerID  Recency
# 0     12346.0      325
# 1     12347.0        2
# 2     12348.0       75
# 3     12349.0       18
# 4     12350.0      310

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['dark_background'])

sns.displot(data = recency_df, x="Recency");
plt.gcf().set_size_inches(16.5, 3)

# %% [markdown]
# ### · Frequency
# ---

# %%
# ▶ Customer ID recognizes the unique Invoice per ID and recognizes how often it is purchased.
frequency_df = df.copy()
frequency_df.drop_duplicates(subset=['CustomerID','InvoiceNo'], keep="first", inplace=True)
frequency_df = frequency_df.groupby('CustomerID', as_index=False)['InvoiceNo'].count()
frequency_df.columns = ['CustomerID','Frequency']
frequency_df.head()
# Out:
#    CustomerID  Frequency
# 0     12346.0          1
# 1     12347.0          7
# 2     12348.0          4
# 3     12349.0          1
# 4     12350.0          1

# %% [markdown]
# ### · Monetary (money)
# ---

# %%
# ▶ Purchase amount = number of purchases * purchase price
df['Total_cost'] = df['UnitPrice'] * df['Quantity']
monetary_df=df.groupby('CustomerID',as_index=False)['Total_cost'].sum()
monetary_df.columns = ['CustomerID','Monetary']
monetary_df.head()
# Out:
#    CustomerID  Monetary
# 0     12346.0  77183.60
# 1     12347.0   4310.00
# 2     12348.0   1797.24
# 3     12349.0   1757.55
# 4     12350.0    334.40

# %%
# ▶ Data merge

# ▶ recency and frequency
rf = recency_df.merge(frequency_df,how='left',on='CustomerID')

# ▶ monetary

rfm = rf.merge(monetary_df,how='left',on='CustomerID')

rfm.head(5)
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     12346.0      325          1  77183.60
# 1     12347.0        2          7   4310.00
# 2     12348.0       75          4   1797.24
# 3     12349.0       18          1   1757.55
# 4     12350.0      310          1    334.40

# %% [markdown]
# ## ** 🥇Session 3 **
# ** ┗ RFM utilization service level measurement **
# ---

# %% [markdown]
# ### · Scaling Data
# ---

# %%
# ▶ Min Max Scale = Technique to standardize the maximum value to 1, minimum value
from sklearn.preprocessing import minmax_scale

# ▶ The smaller the number, the higher the number, the higher the customer who has not been recently purchased recently.
rfm['Recency'] = minmax_scale(rfm['Recency'], axis=0, copy=True)
rfm['Recency'] = 1-rfm['Recency']

rfm['Frequency'] = minmax_scale(rfm['Frequency'], axis=0, copy=True)

rfm['Monetary'] = minmax_scale(rfm['Monetary'], axis=0, copy=True)

# ▶ Score
rfm['Score']=rfm['Recency']+rfm['Frequency']+rfm['Monetary']

# ▶ Score scaling 100 socre
rfm
# Out:
#       CustomerID   Recency  Frequency  Monetary     Score
# 0        12346.0  0.128686   0.000000  0.275443  0.404130
# 1        12347.0  0.994638   0.028846  0.015368  1.038853
# 2        12348.0  0.798928   0.014423  0.006401  0.819751
# 3        12349.0  0.951743   0.000000  0.006259  0.958002
# 4        12350.0  0.168901   0.000000  0.001180  0.170081
# ...          ...       ...        ...       ...       ...
# 4333     18280.0  0.257373   0.000000  0.000631  0.258004
# 4334     18281.0  0.517426   0.000000  0.000275  0.517701
# 4335     18282.0  0.981233   0.004808  0.000622  0.986663
# 4336     18283.0  0.991957   0.072115  0.007463  1.071535
# 4337     18287.0  0.887399   0.009615  0.006544  0.903558
#
# [4338 rows x 5 columns]

# %%
# ▶ Multiply 100 points and scaling with 100 points
rfm['Score']=minmax_scale(rfm['Score'], axis=0, copy=True)*100
rfm['Score']=round(rfm['Score'],0)

# %%
rfm.head(5)
# Out:
#    CustomerID   Recency  Frequency  Monetary  Score
# 0     12346.0  0.128686   0.000000  0.275443   16.0
# 1     12347.0  0.994638   0.028846  0.015368   42.0
# 2     12348.0  0.798928   0.014423  0.006401   33.0
# 3     12349.0  0.951743   0.000000  0.006259   39.0
# 4     12350.0  0.168901   0.000000  0.001180    7.0

# %% [markdown]
# ### · Grade (score) section
# ---

# %%
sns.displot(rfm['Score']);

# %%
rfm.head(5)
# Out:
#    CustomerID   Recency  Frequency  Monetary  Score
# 0     12346.0  0.128686   0.000000  0.275443   16.0
# 1     12347.0  0.994638   0.028846  0.015368   42.0
# 2     12348.0  0.798928   0.014423  0.006401   33.0
# 3     12349.0  0.951743   0.000000  0.006259   39.0
# 4     12350.0  0.168901   0.000000  0.001180    7.0

# %%
# ▶ Give customer rating by score
# 60 points or more very strong
# 40-60 points strong
# 20-40 points Normal
# 10-20 points weak
# 0 ~ 10 points Very Weak

rfm['Grade'] = rfm['Score'].apply(lambda x : '01.Very Strong' if x>=60 else
                                  ('02.Strong' if x>=40 else
                                   ('03.Normal' if x>=20 else
                                    ('04.Weak' if x>=10 else '05.Very Weak'))))
rfm.head(5)
# Out:
#    CustomerID   Recency  Frequency  Monetary  Score         Grade
# 0     12346.0  0.128686   0.000000  0.275443   16.0       04.Weak
# 1     12347.0  0.994638   0.028846  0.015368   42.0     02.Strong
# 2     12348.0  0.798928   0.014423  0.006401   33.0     03.Normal
# 3     12349.0  0.951743   0.000000  0.006259   39.0     03.Normal
# 4     12350.0  0.168901   0.000000  0.001180    7.0  05.Very Weak

# %%
# ▶ LEFT JOIN is the Grade DATA in the existing data
df = pd.merge(df, rfm, how='left', on='CustomerID')
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country       Date  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom 2010-12-01
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom 2010-12-01
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
#
#    Total_cost   Recency  Frequency  Monetary  Score         Grade
# 0       15.30  0.002681   0.158654  0.019227    7.0  05.Very Weak
# ...

# %%
# ▶ Prior to planning, definition of a new COL for the year (※ Preparation for monthly analysis)
df['Date_1'] = df["Date"].dt.strftime("%Y-%m")
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country       Date  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom 2010-12-01
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom 2010-12-01
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01
#
#    Total_cost   Recency  Frequency  Monetary  Score         Grade   Date_1
# ...

# %% [markdown]
# ### · Indicator planning

# %% [markdown]
# #### · Customer status by month
# ---

# %%
# ▶ Monthly user customer status
df_cus = df.groupby('Date_1',as_index=False)['CustomerID'].nunique()
df_cus.tail(5)
# Out:
#      Date_1  CustomerID
# 8   2011-08         935
# 9   2011-09        1266
# 10  2011-10        1364
# 11  2011-11        1664
# 12  2011-12         615

# %%
# ▶ Since the launch of 2010.12, the number of users has increased and the PEAK has been achieved in November 2011, but it plummeted ..
plt.plot(df_cus['Date_1'], df_cus['CustomerID'], label='Customer');
plt.legend();
plt.gcf().set_size_inches(25, 5)

# %% [markdown]
# #### · Number of cases of monthly use
# ---

# %%
# ▶ Number of monthly use cases
df_cnt = df.groupby('Date_1',as_index=False)['InvoiceNo'].nunique()
df_cnt.head(5)
# Out:
#     Date_1  InvoiceNo
# 0  2010-12       1400
# 1  2011-01        987
# 2  2011-02        997
# 3  2011-03       1321
# 4  2011-04       1149

# %%
# ▶ Similar to the number of customers using monthly customers
plt.plot(df_cnt['Date_1'], df_cnt['InvoiceNo'], label='Customer_cnt');
plt.legend();
plt.gcf().set_size_inches(25, 5)

# %% [markdown]
# #### · Country by month
# ---

# %%
df['Country'].nunique()
# Out:
# 37

# %%
# ▶ Monthly use countries
df_country = df.groupby('Date_1',as_index=False)['Country'].nunique()
df_country.head(5)
# Out:
#     Date_1  Country
# 0  2010-12       22
# 1  2011-01       20
# 2  2011-02       24
# 3  2011-03       22
# 4  2011-04       24

# %%
plt.plot(df_country['Date_1'], df_country['Country'], label='Country');
plt.legend();
plt.gcf().set_size_inches(25, 3)

# %%
# Country with the highest loyalty
pd.DataFrame(df.groupby(['Country'])['InvoiceNo'].nunique().sort_values(ascending=False)).head(10)
# Out:
#                 InvoiceNo
# Country
# United Kingdom      16646
# Germany               457
# France                389
# EIRE                  260
# Belgium                98
# Netherlands            94
# Spain                  90
# Portugal               57
# Australia              57
# Switzerland            51

# %% [markdown]
# #### · The proportion of use of Grade by month
# ---

# %%
df_grade = df.groupby(['Date_1', 'Grade'],as_index=False)['CustomerID'].nunique()
df_grade.head(5)
# Out:
#     Date_1           Grade  CustomerID
# 0  2010-12  01.Very Strong          11
# 1  2010-12       02.Strong         397
# 2  2010-12       03.Normal         291
# 3  2010-12         04.Weak          42
# 4  2010-12    05.Very Weak         144

# %%
df_pivot = pd.pivot_table(df_grade,            # Pivot data frame
                      index = 'Date_1',        # Passes in the line
                      columns = 'Grade',       # Heat to enter the column position
                      values = 'CustomerID')   # Open to be used as data

df_pivot.fillna(0, inplace=True)
df_pivot['total'] = df_pivot['01.Very Strong'] + df_pivot['02.Strong'] + df_pivot['03.Normal'] + df_pivot['04.Weak'] + df_pivot['05.Very Weak']


df_pivot.iloc[:,0] = (df_pivot.iloc[:,0] / df_pivot['total'])
df_pivot.iloc[:,1] = (df_pivot.iloc[:,1] / df_pivot['total'])
df_pivot.iloc[:,2] = (df_pivot.iloc[:,2] / df_pivot['total'])
df_pivot.iloc[:,3] = (df_pivot.iloc[:,3] / df_pivot['total'])
df_pivot.iloc[:,4] = (df_pivot.iloc[:,4] / df_pivot['total'])

df_pivot.drop(['total'], axis=1, inplace=True)
df_pivot
# Out:
# Grade    01.Very Strong  02.Strong  03.Normal   04.Weak  05.Very Weak
# Date_1
# 2010-12        0.012429   0.448588   0.328814  0.047458      0.162712
# 2011-01        0.014845   0.450742   0.349528  0.045884      0.139001
# 2011-02        0.014512   0.419525   0.377309  0.056728      0.131926
# 2011-03        0.012320   0.401437   0.388090  0.198152      0.000000
# 2011-04        0.014019   0.420561   0.394860  0.170561      0.000000
# 2011-05        0.012311   0.425189   0.428977  0.133523      0.000000
# 2011-06        0.012109   0.427851   0.560040  0.000000      0.000000
# 2011-07        0.012645   0.443625   0.543730  0.000000      0.000000
# 2011-08        0.012834   0.453476   0.533690  0.000000      0.000000
# 2011-09        0.009479   0.438389   0.552133  0.000000      0.000000
# 2011-10        0.008798   0.397361   0.593842  0.000000      0.000000
# 2011-11        0.007212   0.487380   0.505409  0.000000      0.000000
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
plt.style.use(['dark_background'])

ax = df_pivot.plot(kind='barh', stacked=True, title="years amt", rot=0);
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.1f"%(width*100), xy=(left+width/2, bottom+height/2), ha='center', va='center', color='black');

plt.box(False)
plt.gcf().set_size_inches(25, 15)
plt.show()
